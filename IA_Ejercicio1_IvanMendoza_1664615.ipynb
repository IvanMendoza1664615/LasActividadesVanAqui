# %%
#Tarea 2 Ejercicio Introduccion a Python
#Nombre: Ivan Alejandro Mendoza Alejo
#Matricula: 1664615
#Hora: Sabatino N1-N3

#Ejercicio 1
Nombre = input("¿Cual es tu nombre completo?: ") #Se ingresa nombre con el comando input
Edad = input("¿Cual es tu edad? ") #Aqui se ingresa la edad
Frase = input("Escribe una frase favorita: ") #Se agrega su frase favorita
Autor = input("¿Quien es el autor de la frase?: ") #Se ingresa el autor de la frase

print("Mi nombre es "+ Nombre + " tengo "+ Edad + " años. ") #Se imprime el resultado 
print("Mi frase favorita es: " + Frase )
print("Dicha por " + Autor)
# Out:
# ¿Cual es tu nombre completo?: Ivan Alejandro Mendoza Alejo
# ¿Cual es tu edad? 23
# Escribe una frase favorita: Yo solo se que no se nada
# ¿Quien es el autor de la frase?: Platon
# Mi nombre es Ivan Alejandro Mendoza Alejo tengo 23 años.
# Mi frase favorita es: Yo solo se que no se nada
# Dicha por Platon

# %%
#Ejercicio 2
a = int(input("Ingrese un numero entero: "))#En este apartado se uso el comando int que genera el numero ingresa en un numero entero
b = int(input("Ingrese un numero entero: "))
c = float(input("Ingrese un numero flotante: "))#En este apartado se uso float para que se generara un numero flotante 
d = float(input("Ingrese un numero flotante: "))

#En este apartado se realizan las operaciones solicitadas
e=a+b 
f=a-b
g=a*b
h=a/b
i=c+d
j=c-d
k=c*d
l=c/d

#En este apartado se imprimen los ocho resultados de las operaciones y sus respectivos resultados se separan.
print("La suma de enteros es: "+ str(e))
print("La resta de enteros es: "+ str(f))
print("La multiplicacion de enteros es: "+ str(g))
print("La division de enteros es: "+ str(h))
print("La suma de flotante es: "+ str(i))
print("La resta de flotante es: "+ str(j))
print("La multiplicacion de flotante es: "+ str(k))
print("La division de flotante es: "+ str(h))
# Out:
# Ingrese un numero entero: 30
# Ingrese un numero entero: 60
# Ingrese un numero flotante: 5.86
# Ingrese un numero flotante: 10.6
# La suma de enteros es: 90
# La resta de enteros es: -30
# La multiplicacion de enteros es: 1800
# La division de enteros es: 0.5
# La suma de flotante es: 16.46
# La resta de flotante es: -4.739999999999999
# La multiplicacion de flotante es: 62.116
# La division de flotante es: 0.5

# %%
#Ejercicio 3
#Ejercicio And
#En este ejercico se simulara el funcionamiento de una maquina de prensa donde "x" y "y" son los sensores.
#Los sensores son donde se ponen las manos los cuales significa que no tienes la mano adentro, donde 1 es sensor activo y 0 sensor inactivo
x=int(input("Ingrese valor de sensor 1: "))
y=int(input("Ingrese valor de sensor 2: "))
z = x and y

if (z == 1):
  print("Prensa encendida")
else:
  print("Error mano adentro")
#Ejercicio OR
#En este ejercicio se evaluara el funcionamiento de un led los cuales las entradas son a y b que son switch
#Donde 1 es estado activo y 0 Estado inactivo
a=int(input("Ingrese valor de swtich 1: "))
b=int(input("Ingrese valor de switch 1: "))
c= a or b

if (c == 1):
  print("Led Encendido")
else:
  print("Led Apagado")

#Ejericio NOT
#Se evaluara un funcionamiento de led con una convinacion de un or, and y not
#Donde 1 es activo y 0 es inactivo
g=int(input("Ingrese valor de : "))
h=int(input("Ingrese valor de : "))
#En esta parte se evalua un segmento un poco mas complejo de encender un led 
#El sistema se basa en un circuito de electronica digital
i= not(g and h)
j=( not(g) or h)
k= i or not(j)

if (k == 1):
  print("Led Encendido")
else:
  print("Led Apagado")
# Out:
# Ingrese valor de sensor 1: 1
# Ingrese valor de sensor 2: 1
# Prensa encendida
# Ingrese valor de swtich 1: 1
# Ingrese valor de switch 1: 1
# Led Encendido
# Ingrese valor de : 1
# Ingrese valor de : 1
# Led Apagado
